# %%
import pandas as pd
from IPython.display import display

dados = pd.read_csv('./output/Dados_Final.csv')
dados.set_index('Open time', inplace = True) # Data time como index
dados
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 1999-02-18 16:00:00+03:00  1.12450  1.12500  1.11850  1.11940     880
# 1999-02-18 20:00:00+03:00  1.11960  1.12070  1.11920  1.11980     183
# 1999-02-19 00:00:00+03:00  1.11970  1.12000  1.11810  1.11890     322
# 1999-02-19 04:00:00+03:00  1.11910  1.12060  1.11820  1.12040     486
# 1999-02-19 08:00:00+03:00  1.12060  1.12110  1.11670  1.11840    1318
# ...                            ...      ...      ...      ...     ...
# 2022-08-31 08:00:00+03:00  1.00403  1.00460  0.99741  0.99793   23205
# 2022-08-31 12:00:00+03:00  0.99794  1.00184  0.99714  1.00084   28012
# 2022-08-31 16:00:00+03:00  1.00085  1.00790  0.99952  1.00535   39166
# 2022-08-31 20:00:00+03:00  1.00534  1.00574  1.00355  1.00545   18812
# 2022-09-01 00:00:00+03:00  1.00510  1.00545  1.00200  1.00234   10200
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %%
dados['Long'].value_counts()
# Out:
# 0    27501
# 1     9154
# Name: Long, dtype: int64

# %%
dados['Short'].value_counts()
# Out:
# 0    27942
# 1     8713
# Name: Short, dtype: int64

# %%
# dados.drop(columns='Date' ,inplace=True)
# dados.drop(columns='Open' ,inplace=True)
# dados.drop(columns='High' ,inplace=True)
# dados.drop(columns='Low' ,inplace=True)
# dados.drop(columns='Close' ,inplace=True)
# dados.drop(columns='Volume' ,inplace=True)
# dados.drop(columns='ATR' ,inplace=True)
# dados.drop(columns='EMA50' ,inplace=True)
# dados.drop(columns='EMA144' ,inplace=True)
# dados.drop(columns='EMA200' ,inplace=True)
# dados.drop(columns='Boll50' ,inplace=True)
# dados.drop(columns='Boll144' ,inplace=True)
# dados.drop(columns='Boll200' ,inplace=True)
# dados.drop(columns='ROC50' ,inplace=True)
# dados.drop(columns='ROC144' ,inplace=True)
# dados.drop(columns='ROC200' ,inplace=True)
# dados.drop(columns='CrxFS' ,inplace=True)
# dados.drop(columns='CrxFM' ,inplace=True)
# dados.drop(columns='CrxMS' ,inplace=True)
# dados.drop(columns='RSI' ,inplace=True)
# # dados.drop(columns='Structure' ,inplace=True)
# # dados.drop(columns='ImbLow' ,inplace=True)
# # dados.drop(columns='ImbHigh' ,inplace=True)
# # dados.drop(columns='StructTop' ,inplace=True)
# # dados.drop(columns='StructBottom' ,inplace=True)
# dados.drop(columns='sma' ,inplace=True)
# dados.drop(columns='sd' ,inplace=True)
# dados.drop(columns='lb' ,inplace=True)
# dados.drop(columns='ub' ,inplace=True)
# dados.drop(columns='signal_BB' ,inplace=True)
# dados.drop(columns='signal_rsi' ,inplace=True)
# dados.drop(columns='MMS' ,inplace=True)
# dados.drop(columns='prev' ,inplace=True)


# dados.drop(columns='Date' ,inplace=True)
# dados.drop(columns='open' ,inplace=True)
# dados.drop(columns='high' ,inplace=True)
# dados.drop(columns='low' ,inplace=True)
# dados.drop(columns='close' ,inplace=True)
# dados.drop(columns='volume' ,inplace=True)
# dados.drop(columns='atr' ,inplace=True)
# dados.drop(columns='ema50' ,inplace=True)
# dados.drop(columns='ema200' ,inplace=True)
# # dados.drop(columns='Structure' ,inplace=True)
# dados.drop(columns='imblow' ,inplace=True)
# dados.drop(columns='imbhigh' ,inplace=True)
# dados.drop(columns='structtop' ,inplace=True)
# dados.drop(columns='structbottom' ,inplace=True)
# dados.drop(columns='sma' ,inplace=True)
# dados.drop(columns='sd' ,inplace=True)
# dados.drop(columns='lb' ,inplace=True)
# dados.drop(columns='ub' ,inplace=True)
# dados.drop(columns='rs_14' ,inplace=True)
# dados.drop(columns='rsi_14' ,inplace=True)

#Inner Circle Trade
dados.drop(columns='EMA50' ,inplace=True)
dados.drop(columns='EMA144' ,inplace=True)
dados.drop(columns='EMA200' ,inplace=True)
dados.drop(columns='Boll50' ,inplace=True)
dados.drop(columns='Boll144' ,inplace=True)
dados.drop(columns='Boll200' ,inplace=True)
dados.drop(columns='ROC50' ,inplace=True)
dados.drop(columns='ROC144' ,inplace=True)
dados.drop(columns='ROC200' ,inplace=True)
dados.drop(columns='CrxFS' ,inplace=True)
dados.drop(columns='CrxFM' ,inplace=True)
dados.drop(columns='CrxMS' ,inplace=True)
dados.drop(columns='RSI' ,inplace=True)
dados.drop(columns='sma' ,inplace=True)
dados.drop(columns='sd' ,inplace=True)
dados.drop(columns='lb' ,inplace=True)
dados.drop(columns='ub' ,inplace=True)
dados.drop(columns='signal_BB' ,inplace=True)
dados.drop(columns='signal_rsi' ,inplace=True)
dados.drop(columns='MMS' ,inplace=True)


dados
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 1999-02-18 16:00:00+03:00  1.12450  1.12500  1.11850  1.11940     880
# 1999-02-18 20:00:00+03:00  1.11960  1.12070  1.11920  1.11980     183
# 1999-02-19 00:00:00+03:00  1.11970  1.12000  1.11810  1.11890     322
# 1999-02-19 04:00:00+03:00  1.11910  1.12060  1.11820  1.12040     486
# 1999-02-19 08:00:00+03:00  1.12060  1.12110  1.11670  1.11840    1318
# ...                            ...      ...      ...      ...     ...
# 2022-08-31 08:00:00+03:00  1.00403  1.00460  0.99741  0.99793   23205
# 2022-08-31 12:00:00+03:00  0.99794  1.00184  0.99714  1.00084   28012
# 2022-08-31 16:00:00+03:00  1.00085  1.00790  0.99952  1.00535   39166
# 2022-08-31 20:00:00+03:00  1.00534  1.00574  1.00355  1.00545   18812
# 2022-09-01 00:00:00+03:00  1.00510  1.00545  1.00200  1.00234   10200
#
#                                ATR  Engolfo  FuCandle  Structure  StructTop  \
# Open time
# ...

# %%
x = dados.iloc[:, :-2]
y_l = dados.iloc[:, -2] #Long
y_s = dados.iloc[:, -1] #Short
# y_l = dados.iloc[:, -3] #Long
# y_s = dados.iloc[:, -2] #Short
# dados.drop(columns='Long' ,inplace=True)
# dados.drop(columns='Short' ,inplace=True)
# x = dados.copy()

# %%
x
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 1999-02-18 16:00:00+03:00  1.12450  1.12500  1.11850  1.11940     880
# 1999-02-18 20:00:00+03:00  1.11960  1.12070  1.11920  1.11980     183
# 1999-02-19 00:00:00+03:00  1.11970  1.12000  1.11810  1.11890     322
# 1999-02-19 04:00:00+03:00  1.11910  1.12060  1.11820  1.12040     486
# 1999-02-19 08:00:00+03:00  1.12060  1.12110  1.11670  1.11840    1318
# ...                            ...      ...      ...      ...     ...
# 2022-08-31 08:00:00+03:00  1.00403  1.00460  0.99741  0.99793   23205
# 2022-08-31 12:00:00+03:00  0.99794  1.00184  0.99714  1.00084   28012
# 2022-08-31 16:00:00+03:00  1.00085  1.00790  0.99952  1.00535   39166
# 2022-08-31 20:00:00+03:00  1.00534  1.00574  1.00355  1.00545   18812
# 2022-09-01 00:00:00+03:00  1.00510  1.00545  1.00200  1.00234   10200
#
#                                ATR  Engolfo  FuCandle  Structure  StructTop  \
# Open time
# ...

# %%
#SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y_l, test_size = 0.25, shuffle = False)

print(treino_x.shape)
print(teste_x.shape)
#print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))

modelo = SVC()
modelo.fit(treino_x, treino_y) # modelo.fit(treino_x, treino_y.values.ravel()) # com treino_y da um aviso, estudar "numpy.ravel" (https://numpy.org/doc/stable/reference/generated/numpy.ravel.html#numpy.ravel)
previsoes_l = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes_l) * 100 # taxa de acerto
print("A acurácia do Long foi %.2f%%" % acuracia)
# Out:
# (27491, 15)
# (9164, 15)
# A acurácia do Long foi 76.33%

# %%
teste_x
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 2016-10-11 20:00:00+03:00  1.10687  1.10692  1.10486  1.10530   22097
# 2016-10-12 00:00:00+03:00  1.10530  1.10673  1.10410  1.10439   15803
# 2016-10-12 04:00:00+03:00  1.10439  1.10567  1.10439  1.10481   16448
# 2016-10-12 08:00:00+03:00  1.10481  1.10607  1.10164  1.10241   32242
# 2016-10-12 12:00:00+03:00  1.10242  1.10288  1.10094  1.10212   28439
# ...                            ...      ...      ...      ...     ...
# 2022-08-31 08:00:00+03:00  1.00403  1.00460  0.99741  0.99793   23205
# 2022-08-31 12:00:00+03:00  0.99794  1.00184  0.99714  1.00084   28012
# 2022-08-31 16:00:00+03:00  1.00085  1.00790  0.99952  1.00535   39166
# 2022-08-31 20:00:00+03:00  1.00534  1.00574  1.00355  1.00545   18812
# 2022-09-01 00:00:00+03:00  1.00510  1.00545  1.00200  1.00234   10200
#
#                                ATR  Engolfo  FuCandle  Structure  StructTop  \
# Open time
# ...

# %%
#SVM
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

treino_x, teste_x, treino_y, teste_y = train_test_split(x, y_s, test_size = 0.25, shuffle = False)

print(treino_x.shape)
print(teste_x.shape)
#print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))

modelo = SVC()
modelo.fit(treino_x, treino_y) # modelo.fit(treino_x, treino_y.values.ravel()) # com treino_y da um aviso, estudar "numpy.ravel" (https://numpy.org/doc/stable/reference/generated/numpy.ravel.html#numpy.ravel)
previsoes_s = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes_s) * 100 # taxa de acerto
print("A acurácia do Short foi %.2f%%" % acuracia)
# Out:
# (27491, 15)
# (9164, 15)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Marco\Documents\Unipampa\2022-2\Project_TCC\Marco\ML.ipynb Célula 9 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Marco/Documents/Unipampa/2022-2/Project_TCC/Marco/ML.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a> #print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))
#      <a href='vscode-notebook-cell:/c%3A/Users/Marco/Documents/Unipampa/2022-2/Project_TCC/Marco/ML.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> modelo = SVC()
# ...

# %%
print(previsoes_l)
# Out:
# [0 0 0 ... 0 0 0]

# %%
previsoes_s
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Dados_SVM = teste_x
Dados_SVM['Long'] = previsoes_l
Dados_SVM['Short'] = previsoes_s

# %%
display(Dados_SVM)
display(Dados_SVM['Long'].value_counts())
display(Dados_SVM['Short'].value_counts())
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 2016-10-11 00:00:00+03:00  1.11346  1.11419  1.11299  1.11313   10090
# 2016-10-11 04:00:00+03:00  1.11314  1.11373  1.11192  1.11335   16666
# 2016-10-11 08:00:00+03:00  1.11335  1.11346  1.11057  1.11113   27688
# 2016-10-11 12:00:00+03:00  1.11112  1.11161  1.10713  1.10882   31657
# 2016-10-11 16:00:00+03:00  1.10883  1.10983  1.10537  1.10689   39402
# ...                            ...      ...      ...      ...     ...
# 2022-08-30 08:00:00+03:00  0.99997  1.00342  0.99825  1.00250   24376
# 2022-08-30 12:00:00+03:00  1.00250  1.00549  1.00086  1.00115   24730
# 2022-08-30 16:00:00+03:00  1.00115  1.00414  0.99826  1.00238   38294
# 2022-08-30 20:00:00+03:00  1.00239  1.00316  1.00104  1.00137   16687
# 2022-08-31 00:00:00+03:00  1.00122  1.00346  1.00105  1.00273    6002
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %%
Dados_SVM.to_csv('./output/Dados_Prev_SVM.csv')

# %% [markdown]
# ### Arvore de decisão

# %%
#Arvore de decisão
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

SEED = 5
np.random.seed(SEED)
# raw_treino_x, raw_teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,
#                                                         shuffle = False)
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y_l, test_size = 0.25,
                                                         shuffle = False)
print(treino_x.shape)
print(teste_x.shape)
print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))

#Precisa Escalar
# scaler = StandardScaler()
# scaler.fit(raw_treino_x)
# treino_x = scaler.transform(raw_treino_x)
# teste_x = scaler.transform(raw_teste_x)

modelo = DecisionTreeClassifier(max_depth=5) #definição da profundidade
modelo.fit(treino_x, treino_y)
previsoes_ad_l = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes_ad_l) * 100 # taxa de acerto
print("A acurácia do Long foi %.2f%%" % acuracia)
# Out:
# (27486, 36)
# (9163, 36)
# Treinaremos com 27486 elementos e testaremos com 9163 elementos
# A acurácia do Long foi 77.08%

# %%
#Arvore de decisão
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

SEED = 5
np.random.seed(SEED)
# raw_treino_x, raw_teste_x, treino_y, teste_y = train_test_split(x, y, test_size = 0.25,
#                                                         shuffle = False)
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y_s, test_size = 0.25,
                                                         shuffle = False)
print(treino_x.shape)
print(teste_x.shape)
print("Treinaremos com %d elementos e testaremos com %d elementos" % (len(treino_x), len(teste_x)))

#Precisa Escalar
# scaler = StandardScaler()
# scaler.fit(raw_treino_x)
# treino_x = scaler.transform(raw_treino_x)
# teste_x = scaler.transform(raw_teste_x)

modelo = DecisionTreeClassifier(max_depth=7) #definição da profundidade
modelo.fit(treino_x, treino_y)
previsoes_ad_s = modelo.predict(teste_x)

acuracia = accuracy_score(teste_y, previsoes_ad_s) * 100 # taxa de acerto
print("A acurácia do Short foi %.2f%%" % acuracia)
# Out:
# (27486, 36)
# (9163, 36)
# Treinaremos com 27486 elementos e testaremos com 9163 elementos
# A acurácia do Short foi 76.58%

# %%
Dados_DT = teste_x
Dados_DT['Long'] = previsoes_ad_l
Dados_DT['Short'] = previsoes_ad_s
Dados_DT.to_csv('./output/Dados_Prev_DT.csv')

# %%
display(Dados_DT)
display(Dados_DT['Long'].value_counts())
display(Dados_DT['Short'].value_counts())
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 2016-10-11 00:00:00+03:00  1.11346  1.11419  1.11299  1.11313   10090
# 2016-10-11 04:00:00+03:00  1.11314  1.11373  1.11192  1.11335   16666
# 2016-10-11 08:00:00+03:00  1.11335  1.11346  1.11057  1.11113   27688
# 2016-10-11 12:00:00+03:00  1.11112  1.11161  1.10713  1.10882   31657
# 2016-10-11 16:00:00+03:00  1.10883  1.10983  1.10537  1.10689   39402
# ...                            ...      ...      ...      ...     ...
# 2022-08-30 08:00:00+03:00  0.99997  1.00342  0.99825  1.00250   24376
# 2022-08-30 12:00:00+03:00  1.00250  1.00549  1.00086  1.00115   24730
# 2022-08-30 16:00:00+03:00  1.00115  1.00414  0.99826  1.00238   38294
# 2022-08-30 20:00:00+03:00  1.00239  1.00316  1.00104  1.00137   16687
# 2022-08-31 00:00:00+03:00  1.00122  1.00346  1.00105  1.00273    6002
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %% [markdown]
# ### Floresta Aleátoria

# %%
#Floresta Aleatoria
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y_l, test_size = 0.25, random_state = 0, shuffle=False)

modelo = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0) #n_estimators=100, n_jobs=-1, random_state=0
modelo.fit(X_train, y_train)

y_pred_fa_l = modelo.predict(X_test)
acuracia = accuracy_score(y_test, y_pred_fa_l) * 100 # taxa de acerto
print("A acurácia do Long foi %.2f%%" % acuracia)
# Out:
# A acurácia do Long foi 76.12%

# %%
#Floresta Aleatoria
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y_s, test_size = 0.25, random_state = 0, shuffle=False)

modelo = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0) #n_estimators=100, n_jobs=-1, random_state=0
modelo.fit(X_train, y_train)

y_pred_fa_s = modelo.predict(X_test)
acuracia = accuracy_score(y_test, y_pred_fa_s) * 100 # taxa de acerto
print("A acurácia do Short foi %.2f%%" % acuracia)
# Out:
# A acurácia do Short foi 75.41%

# %%
Dados_RF = X_test
Dados_RF['Long'] = y_pred_fa_l
Dados_RF['Short'] = y_pred_fa_s
Dados_RF
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 2016-10-11 00:00:00+03:00  1.11346  1.11419  1.11299  1.11313   10090
# 2016-10-11 04:00:00+03:00  1.11314  1.11373  1.11192  1.11335   16666
# 2016-10-11 08:00:00+03:00  1.11335  1.11346  1.11057  1.11113   27688
# 2016-10-11 12:00:00+03:00  1.11112  1.11161  1.10713  1.10882   31657
# 2016-10-11 16:00:00+03:00  1.10883  1.10983  1.10537  1.10689   39402
# ...                            ...      ...      ...      ...     ...
# 2022-08-30 08:00:00+03:00  0.99997  1.00342  0.99825  1.00250   24376
# 2022-08-30 12:00:00+03:00  1.00250  1.00549  1.00086  1.00115   24730
# 2022-08-30 16:00:00+03:00  1.00115  1.00414  0.99826  1.00238   38294
# 2022-08-30 20:00:00+03:00  1.00239  1.00316  1.00104  1.00137   16687
# 2022-08-31 00:00:00+03:00  1.00122  1.00346  1.00105  1.00273    6002
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %%
display(Dados_RF['Long'].value_counts())
display(Dados_RF['Short'].value_counts())
# Out:
# 0    8671
# 1     492
# Name: Long, dtype: int64
# 0    8653
# 1     510
# Name: Short, dtype: int64

# %%
Dados_RF.to_csv('./output/Dados_Prev_RF.csv')

# %% [markdown]
# ### Rede Neural

# %%
#Rede Neural
from sklearn.neural_network import MLPClassifier
from sklearn import neural_network

X_train, X_test, y_train, y_test = train_test_split(x, y_l, test_size = 0.25, shuffle=False, random_state = 0)

rede = neural_network.MLPClassifier() #0.001 #max_iter=numero_de_epocas,verbose=False,momentum=momento,learning_rate='constant',learning_rate_init=taxa_de_aprendizado

rede.fit(X_train,y_train.values.ravel());

pred_y_rn_l = rede.predict(X_test)
print('Previsão Long da rede: ',pred_y_rn_l)
# Out:
# Previsão Long da rede:  [0 0 0 ... 0 0 0]

# %%
acuracia = accuracy_score(y_test, pred_y_rn_l) * 100 # taxa de acerto
print("A acurácia do Long foi %.2f%%" % acuracia)
# Out:
# A acurácia do Long foi 76.33%

# %%
X_test
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 2016-10-11 00:00:00+03:00  1.11346  1.11419  1.11299  1.11313   10090
# 2016-10-11 04:00:00+03:00  1.11314  1.11373  1.11192  1.11335   16666
# 2016-10-11 08:00:00+03:00  1.11335  1.11346  1.11057  1.11113   27688
# 2016-10-11 12:00:00+03:00  1.11112  1.11161  1.10713  1.10882   31657
# 2016-10-11 16:00:00+03:00  1.10883  1.10983  1.10537  1.10689   39402
# ...                            ...      ...      ...      ...     ...
# 2022-08-30 08:00:00+03:00  0.99997  1.00342  0.99825  1.00250   24376
# 2022-08-30 12:00:00+03:00  1.00250  1.00549  1.00086  1.00115   24730
# 2022-08-30 16:00:00+03:00  1.00115  1.00414  0.99826  1.00238   38294
# 2022-08-30 20:00:00+03:00  1.00239  1.00316  1.00104  1.00137   16687
# 2022-08-31 00:00:00+03:00  1.00122  1.00346  1.00105  1.00273    6002
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %%
#Rede Neural
from sklearn.neural_network import MLPClassifier
from sklearn import neural_network

X_train, X_test, y_train, y_test = train_test_split(x, y_s, test_size = 0.25, shuffle=False, random_state = 0)

rede = neural_network.MLPClassifier() #0.001 #max_iter=numero_de_epocas,verbose=False,momentum=momento,learning_rate='constant',learning_rate_init=taxa_de_aprendizado

rede.fit(X_train,y_train.values.ravel());

pred_y_rn_s = rede.predict(X_test)
print('Previsão Short da rede: ',pred_y_rn_s)
# Out:
# Previsão Short da rede:  [1 1 1 ... 1 1 1]

# %%
acuracia = accuracy_score(y_test, pred_y_rn_s) * 100 # taxa de acerto
print("A acurácia do Short foi %.2f%%" % acuracia)
# Out:
# A acurácia do Short foi 24.32%

# %%
Dados_RN = X_test
Dados_RN['Long'] = pred_y_rn_l
Dados_RN['Short'] = pred_y_rn_s
Dados_RN
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 2016-10-11 00:00:00+03:00  1.11346  1.11419  1.11299  1.11313   10090
# 2016-10-11 04:00:00+03:00  1.11314  1.11373  1.11192  1.11335   16666
# 2016-10-11 08:00:00+03:00  1.11335  1.11346  1.11057  1.11113   27688
# 2016-10-11 12:00:00+03:00  1.11112  1.11161  1.10713  1.10882   31657
# 2016-10-11 16:00:00+03:00  1.10883  1.10983  1.10537  1.10689   39402
# ...                            ...      ...      ...      ...     ...
# 2022-08-30 08:00:00+03:00  0.99997  1.00342  0.99825  1.00250   24376
# 2022-08-30 12:00:00+03:00  1.00250  1.00549  1.00086  1.00115   24730
# 2022-08-30 16:00:00+03:00  1.00115  1.00414  0.99826  1.00238   38294
# 2022-08-30 20:00:00+03:00  1.00239  1.00316  1.00104  1.00137   16687
# 2022-08-31 00:00:00+03:00  1.00122  1.00346  1.00105  1.00273    6002
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %%
display(Dados_RN['Long'].value_counts())
display(Dados_RN['Short'].value_counts())
# Out:
# 0    9162
# 1       1
# Name: Long, dtype: int64
# 1    9162
# 0       1
# Name: Short, dtype: int64

# %%
Dados_RN.to_csv('./output/Dados_Prev_RN.csv')

# %%
# import matplotlib.pyplot

# matplotlib.pyplot.plot(dados.index, dados['Close'])
# matplotlib.pyplot.plot(dados.index, dados['Op'], marker='o', markersize=6, color='green')
# matplotlib.pyplot.show()

# %%
# import cufflinks as cf

# cf.set_config_file(offline=True)
# dados['Close'].iplot(kind='line', color='blue')

# %%
dados
# Out:
#                               Open     High      Low    Close  Volume  \
# Open time
# 1999-02-18 16:00:00+03:00  1.12450  1.12500  1.11850  1.11940     880
# 1999-02-18 20:00:00+03:00  1.11960  1.12070  1.11920  1.11980     183
# 1999-02-19 00:00:00+03:00  1.11970  1.12000  1.11810  1.11890     322
# 1999-02-19 04:00:00+03:00  1.11910  1.12060  1.11820  1.12040     486
# 1999-02-19 08:00:00+03:00  1.12060  1.12110  1.11670  1.11840    1318
# ...                            ...      ...      ...      ...     ...
# 2022-08-30 08:00:00+03:00  0.99997  1.00342  0.99825  1.00250   24376
# 2022-08-30 12:00:00+03:00  1.00250  1.00549  1.00086  1.00115   24730
# 2022-08-30 16:00:00+03:00  1.00115  1.00414  0.99826  1.00238   38294
# 2022-08-30 20:00:00+03:00  1.00239  1.00316  1.00104  1.00137   16687
# 2022-08-31 00:00:00+03:00  1.00122  1.00346  1.00105  1.00273    6002
#
#                                ATR    EMA50   EMA144   EMA200   Boll50  ...  \
# ...

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# fig , ax = plt.subplots();
# ax.plot(teste_x['Close'], label='teste')
